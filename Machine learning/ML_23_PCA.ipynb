# %% [markdown]
# **1. What are the key reasons for reducing the dimensionality of a dataset? What are the major
# disadvantages?**

# %% [markdown]
# Dimensionality reduction refers to techniques that reduce the number of input variables in a dataset.
#
# More input features often make a predictive modeling task more challenging to model, more generally referred to as the curse of dimensionality.Having a large number of dimensions in the feature space can mean that the volume of that space is very large, and in turn, the points that we have in that space (rows of data) often represent a small and non-representative sample.
#
# The performance of machine learning algorithms can degrade with too many input variables.

# %% [markdown]
# **2. What is the dimensionality curse?**

# %% [markdown]
# The curse of dimensionality basically refers to the difficulties a machine learning algorithm faces when working with data in the higher dimensions, that did not exist in the lower dimensions. This happens because when you add dimensions (features), the minimum data requirements also increase rapidly.
#
# **Sparsity of data occurs when moving to higher dimensions. the volume of the space represented grows so quickly that the data cannot keep up and thus becomes sparse**  The sparsity issue is a major one for anyone whose goal has some statistical significance.
#
# ![curse-of-dimensionality-61461.jpg](data:image/jpeg;base64,...)
#
# As the data space seen above moves from one dimension to two dimensions and finally to three dimensions, **the given data fills less and less of the data space.  In order to maintain an accurate representation of the space, the data for analysis grows exponentially.**
#
#
# The second issue that arises is related to sorting or classifying the data.  **In low dimensional spaces, data may seem very similar but the higher the dimension the further these data points may seem to be.  The two wind turbines below seem very close to each other in two dimensions but separate when viewed in a third dimension.**  This is the same effect the curse of dimensionality has on data.
#
# ![curse-of-dimensionality-5166894.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **3. Tell if its possible to reverse the process of reducing the dimensionality of a dataset? If so, how
# can you go about doing it? If not, what is the reason?**

# %% [markdown]
# When dealing with high dimensional data, it is often useful to reduce the dimensionality by projecting the data to a lower dimensional subspace which captures the “essence” of the data. This is called dimensionality reduction.
#
# The fundamental reason for the curse of dimensionality is that high-dimensional functions have the potential to be much more complicated than low-dimensional ones, and that those complications are harder to discern. The only way to beat the curse is to incorporate knowledge about the data that is correct.
#
# **Techniques for Dimensionality Reduction:**
#
# ***Feature Selection Methods:***
#
# Feature selection is different from dimensionality reduction. Both methods seek to reduce the number of attributes in the dataset, but a dimensionality reduction method do so by creating new combinations of attributes, where as feature selection methods include and exclude attributes present in the data without changing them.
#
# There are three general classes of feature selection algorithms: filter methods, wrapper methods and embedded methods.
#
# Filter feature selection methods apply a statistical measure to assign a scoring to each feature. The features are ranked by the score and either selected to be kept or removed from the dataset.Some examples of some filter methods include the Chi squared test, information gain and correlation coefficient scores.
#
# ***Wrapper Methods:***
#
# Wrapper methods consider the selection of a set of features as a search problem, where different combinations are prepared, evaluated and compared to other combinations. A predictive model is used to evaluate a combination of features and assign a score based on model accuracy.
#
# An example if a wrapper method is the recursive feature elimination algorithm.
#
# ***Embedded Methods:***
#
# Embedded methods learn which features best contribute to the accuracy of the model while the model is being created. The most common type of embedded feature selection methods are regularization methods.
#
# **Matrix Factorization**
#
# The parts can then be ranked and a subset of those parts can be selected that best captures the salient structure of the matrix that can be used to represent the dataset.
#
# The most common method for ranking the components is principal components analysis, or PCA for short.
#
# **Manifold Learning**
#
# These techniques are sometimes referred to as “manifold learning” and are used to create a low-dimensional projection of high-dimensional data, often for the purposes of data visualization.
#
# The projection is designed to both create a low-dimensional representation of the dataset whilst best preserving the salient structure or relationships in the data.
#
# Examples of manifold learning techniques include:
#
# Kohonen Self-Organizing Map (SOM).
# Sammons Mapping
# Multidimensional Scaling (MDS)
# t-distributed Stochastic Neighbor Embedding (t-SNE).
#
# **Autoencoder Methods**
#
# An auto-encoder is a kind of unsupervised neural network that is used for dimensionality reduction and feature discovery. More precisely, an auto-encoder is a feedforward neural network that is trained to predict the input itself.
#
# A network model is used that seeks to compress the data flow to a bottleneck layer with far fewer dimensions than the original input data. The part of the model prior to and including the bottleneck is referred to as the encoder, and the part of the model that reads the bottleneck output and reconstructs the input is called the decoder.
#
# After training, the decoder is discarded and the output from the bottleneck is used directly as the reduced dimensionality of the input. Inputs transformed by this encoder can then be fed into another model, not necessarily a neural network model.

# %% [markdown]
# **4. Can PCA be utilized to reduce the dimensionality of a nonlinear dataset with a lot of variables?**

# %% [markdown]
# PCA (Principal Component Analysis) is a linear dimensionality reduction technique, meaning it works best when the relationships between variables in the dataset are approximately linear. It may not be effective in reducing the dimensionality of a nonlinear dataset with a lot of variables. Nonlinear dimensionality reduction techniques such as Isomap or t-SNE might be more appropriate for this type of dataset.

# %% [markdown]
# **5. Assume you&#39;re running PCA on a 1,000-dimensional dataset with a 95 percent explained variance
# ratio. What is the number of dimensions that the resulting dataset would have?**

# %% [markdown]
# When running PCA on a 1,000-dimensional dataset with a 95% explained variance ratio, the number of dimensions in the resulting dataset would be the number of principal components (PCs) required to retain 95% of the explained variance.
#
# To find this number, we would need to calculate the explained variance for each PC, starting with the first PC and moving on to the next until we reach the desired explained variance ratio. The number of PCs that are required to reach the 95% explained variance ratio is the number of dimensions in the resulting dataset.
#
# It's hard to tell exactly how many dimension would be in the resulting dataset without the data and the way you run the PCA, but it's likely to be less than the original 1,000 dimension.

# %% [markdown]
# **6. Will you use vanilla PCA, incremental PCA, randomized PCA, or kernel PCA in which situations?**

# %% [markdown]
# Here's a summary of when you might use different types of PCA:
#
# Vanilla PCA: This is the basic form of PCA and is useful **when the dataset is small to medium-sized and fits in memory. It works well when the data is linearly separable and the principal components are well-defined.**
#
# Incremental PCA: This variation of PCA is useful **when the dataset is too large to fit in memory. It allows you to compute the PCs incrementally, in small batches, so that you don't have to load the entire dataset into memory at once.**
#
# Randomized PCA: This variation of PCA is useful **when the dataset is very large and the PCs can be approximated with a sufficient degree of accuracy. It works by randomly selecting a subset of the data and using that subset to approximate the PCs.**
#
# Kernel PCA: This variation of PCA is useful **when the data is not linearly separable and the principal components are not well-defined.** It allows you to map the data to a higher-dimensional space where it becomes linearly separable, and then applies PCA to this mapped data.
#
# In summary, Vanilla PCA is suitable for datasets that are small to medium-sized and fit in memory, Incremental PCA is used when the dataset is too large to fit in memory, Randomized PCA is used when the dataset is very large and the PCs can be approximated with a sufficient degree of accuracy, and Kernel PCA is used when the data is not linearly separable and the principal components are not well-defined.

# %% [markdown]
# **7. How do you assess a dimensionality reduction algorithm&#39;s success on your dataset?**

# %% [markdown]
# One way to assess the success of a dimensionality reduction algorithm on a dataset is to evaluate the explained variance ratio. This is the proportion of the total variance in the data that is explained by the reduced dataset. A higher explained variance ratio indicates that more of the important information in the data has been retained. Another way to assess success is to evaluate the performance of a classifier or regressor that is trained on the reduced dataset, compared to the performance of the same classifier or regressor trained on the original dataset.

# %% [markdown]
# **8. Is it logical to use two different dimensionality reduction algorithms in a chain?**

# %% [markdown]
# It can be logical to use two different dimensionality reduction algorithms in a chain, depending on the specific problem and the characteristics of the dataset. For example, if the first dimensionality reduction algorithm is not able to sufficiently reduce the dimensionality of the data, a second algorithm could be used to further reduce the dimensionality. Additionally, different dimensionality reduction algorithms can be used to capture different types of information in the data. However, it's important to note that applying multiple dimensionality reduction algorithms can also lead to overfitting and loss of important information in the dataset, so it's important to carefully evaluate the performance of the pipeline.
